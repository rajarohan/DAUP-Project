# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("muhammadroshaanriaz/e-commerce-trends-a-guide-to-leveraging-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/e-commerce-trends-a-guide-to-leveraging-dataset

# %%
ls /kaggle/input/e-commerce-trends-a-guide-to-leveraging-dataset/ecommerce_product_dataset2.csv
# Out:
# ecommerce_product_dataset2.csv  ecommerce_product_dataset.csv

# %%
path = '/kaggle/input/e-commerce-trends-a-guide-to-leveraging-dataset/ecommerce_product_dataset2.csv'

# %%
import pandas as pd
df = pd.read_csv(path)
df
# Out:
#      ProductID       ProductName     Category   Price  Rating  NumReviews  \
# 0            1        Headphones  Electronics  400.31     1.7        3772
# 1            2        Headphones  Electronics  235.03     2.3        2919
# 2            3        Smartwatch  Electronics  417.90     1.8        1184
# 3            4        Smartphone  Electronics  152.70     3.4        2047
# 4            5            Laptop  Electronics  394.74     1.8        1267
# ..         ...               ...          ...     ...     ...         ...
# 995        996     Throw Blanket     Blankets  207.72     2.3        1973
# 996        997    Fleece Blanket     Blankets  268.60     3.2         841
# 997        998     Throw Blanket     Blankets   92.74     2.8        3454
# 998        999  Weighted Blanket     Blankets  152.28     1.3        2850
# 999       1000     Throw Blanket     Blankets  136.53     2.0        4055
#
#      StockQuantity  Discount  Sales   DateAdded           City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ProductID                          1000 non-null   int64
#  1   ProductName                        1000 non-null   object
#  2   Category                           1000 non-null   object
#  3   Price                              1000 non-null   float64
#  4   Rating                             1000 non-null   float64
#  5   NumReviews                         1000 non-null   int64
#  6   StockQuantity                      1000 non-null   int64
#  7   Discount                           1000 non-null   float64
#  8   Sales                              1000 non-null   int64
#  9   DateAdded                          1000 non-null   object
#  10  City                               1000 non-null   object
# ...

# %%
df.describe()
# Out:
#          ProductID       Price       Rating   NumReviews  StockQuantity  \
# count  1000.000000  1000.00000  1000.000000  1000.000000    1000.000000
# mean    500.500000   253.77551     3.025600  2498.753000     495.395000
# std     288.819436   141.40362     1.151004  1463.241871     292.799253
# min       1.000000    10.11000     1.000000     3.000000       0.000000
# 25%     250.750000   133.09250     2.100000  1201.750000     241.750000
# 50%     500.500000   251.31000     3.100000  2476.000000     505.000000
# 75%     750.250000   375.82750     4.000000  3797.500000     743.500000
# max    1000.000000   499.74000     5.000000  4994.000000     993.000000
#
#           Discount        Sales
# count  1000.000000  1000.000000
# mean      0.251640  1011.037000
# std       0.146455   582.113466
# min       0.000000     0.000000
# 25%       0.130000   502.000000
# 50%       0.250000   998.000000
# 75%       0.380000  1540.000000
# max       0.500000  1997.000000

# %%
df['ProductName'].nunique()
# Out:
# 100

# %%
df['Category'].nunique()
# Out:
# 25

# %%
df['City'].nunique()
# Out:
# 101

# %%
df = df.drop(['City', 'Category', 'ProductName', 'DateAdded'], axis=1)
df['Stock In Vast or Limited Quantity'] = df['Stock In Vast or Limited Quantity'].replace({'True': 1, 'False': 0})
df['Stock In Vast or Limited Quantity'] = df['Stock In Vast or Limited Quantity'].astype(int)
df
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ProductID                          1000 non-null   int64
#  1   Price                              1000 non-null   float64
#  2   Rating                             1000 non-null   float64
#  3   NumReviews                         1000 non-null   int64
#  4   StockQuantity                      1000 non-null   int64
#  5   Discount                           1000 non-null   float64
#  6   Sales                              1000 non-null   int64
#  7   Stock In Vast or Limited Quantity  1000 non-null   int64
# dtypes: float64(3), int64(5)
# memory usage: 62.6 KB
#          ProductID       Price       Rating   NumReviews  StockQuantity  \
# count  1000.000000  1000.00000  1000.000000  1000.000000    1000.000000
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


X = df.drop(columns=["Sales"])
y = df["Sales"]

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)


rf_rmse = np.sqrt(mean_squared_error(y_test, rf_preds))
rf_mae = mean_absolute_error(y_test, rf_preds)
print(f"Random Forest - RMSE: {rf_rmse}, MAE: {rf_mae}")
# Out:
# Random Forest - RMSE: 612.8419243393846, MAE: 531.5489

# %%
svm_model = SVR(kernel="rbf")
svm_model.fit(X_train, y_train)
svm_preds = svm_model.predict(X_test)


svm_rmse = np.sqrt(mean_squared_error(y_test, svm_preds))
svm_mae = mean_absolute_error(y_test, svm_preds)
print(f"SVM - RMSE: {svm_rmse}, MAE: {svm_mae}")
# Out:
# SVM - RMSE: 588.6869465974419, MAE: 513.6946706402053

# %%
cnn_model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dense(32, activation="relu"),
    Dense(1)
])

cnn_model.compile(optimizer="adam", loss="mse")


cnn_model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=1)


cnn_preds = cnn_model.predict(X_test).flatten()


cnn_rmse = np.sqrt(mean_squared_error(y_test, cnn_preds))
cnn_mae = mean_absolute_error(y_test, cnn_preds)
print(f"CNN - RMSE: {cnn_rmse}, MAE: {cnn_mae}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1349873.8750
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1386155.7500
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1385941.8750
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1225805.6250
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1009092.8125
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 697573.8750
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 440888.7500
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 369741.5000
# Epoch 9/50
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.title("Box Plot to Detect Outliers")
plt.show()

# %%
from scipy.stats import skew, kurtosis

for col in df.columns:
  if pd.api.types.is_numeric_dtype(df[col]):
    print(f"Feature: {col}")
    print(f"Skewness: {skew(df[col])}")
    print(f"Kurtosis: {kurtosis(df[col])}")
    print("---")
# Out:
# Feature: ProductID
# Skewness: 0.0
# Kurtosis: -1.2000024000024
# ---
# Feature: Price
# Skewness: 0.03155748245799363
# Kurtosis: -1.1633253863088429
# ---
# Feature: Rating
# Skewness: -0.07866311372644132
# Kurtosis: -1.152347403928072
# ---
# Feature: NumReviews
# Skewness: 0.00014016196344590563
# Kurtosis: -1.2429489652021495
# ---
# Feature: StockQuantity
# Skewness: -0.0221788859958838
# Kurtosis: -1.2287422392663008
# ---
# Feature: Discount
# Skewness: 0.0005911638638327764
# Kurtosis: -1.2010633467658627
# ---
# Feature: Sales
# Skewness: -0.017150536400448935
# Kurtosis: -1.209237698047043
# ---
# Feature: Stock In Vast or Limited Quantity
# Skewness: 0.01600051202457744
# Kurtosis: -1.9997439836149513
# ---

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_no_outliers = df[~((df < lower_bound) | (df > upper_bound)).any(axis=1)]

print(f"Original Dataset Shape: {df.shape}")
print(f"After Removing Outliers: {df_no_outliers.shape}")
# Out:
# Original Dataset Shape: (1000, 8)
# After Removing Outliers: (1000, 8)

# %%
from scipy.stats import skew, kurtosis

for col in df.columns:
  if pd.api.types.is_numeric_dtype(df[col]):
    print(f"Feature: {col}")
    print(f"Skewness: {skew(df[col])}")
    print(f"Kurtosis: {kurtosis(df[col])}")
    print("---")
# Out:
# Feature: ProductID
# Skewness: 0.0
# Kurtosis: -1.2000024000024
# ---
# Feature: Price
# Skewness: 0.03155748245799363
# Kurtosis: -1.1633253863088429
# ---
# Feature: Rating
# Skewness: -0.07866311372644132
# Kurtosis: -1.152347403928072
# ---
# Feature: NumReviews
# Skewness: 0.00014016196344590563
# Kurtosis: -1.2429489652021495
# ---
# Feature: StockQuantity
# Skewness: -0.0221788859958838
# Kurtosis: -1.2287422392663008
# ---
# Feature: Discount
# Skewness: 0.0005911638638327764
# Kurtosis: -1.2010633467658627
# ---
# Feature: Sales
# Skewness: -0.017150536400448935
# Kurtosis: -1.209237698047043
# ---
# Feature: Stock In Vast or Limited Quantity
# Skewness: 0.01600051202457744
# Kurtosis: -1.9997439836149513
# ---

# %%
X_clean = df_no_outliers.drop(columns=["Sales"])
y_clean = df_no_outliers["Sales"]

scaler = MinMaxScaler()
X_scaled_clean = scaler.fit_transform(X_clean)

X_train, X_test, y_train, y_test = train_test_split(X_scaled_clean, y_clean, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)

rf_rmse = np.sqrt(mean_squared_error(y_test, rf_preds))
rf_mae = mean_absolute_error(y_test, rf_preds)
print(f"Random Forest (After Outlier Removal) - RMSE: {rf_rmse}, MAE: {rf_mae}")
# Out:
# Random Forest (After Outlier Removal) - RMSE: 612.8419243393846, MAE: 531.5489

# %%
svm_model = SVR(kernel="rbf")
svm_model.fit(X_train, y_train)
svm_preds = svm_model.predict(X_test)

svm_rmse = np.sqrt(mean_squared_error(y_test, svm_preds))
svm_mae = mean_absolute_error(y_test, svm_preds)
print(f"SVM (After Outlier Removal) - RMSE: {svm_rmse}, MAE: {svm_mae}")
# Out:
# SVM (After Outlier Removal) - RMSE: 588.6869465974419, MAE: 513.6946706402053

# %%
cnn_model = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dense(32, activation="relu"),
    Dense(1)
])

cnn_model.compile(optimizer="adam", loss="mse")

cnn_model.fit(X_train, y_train, epochs=50, batch_size=16, verbose=1)

cnn_preds = cnn_model.predict(X_test).flatten()

cnn_rmse = np.sqrt(mean_squared_error(y_test, cnn_preds))
cnn_mae = mean_absolute_error(y_test, cnn_preds)
print(f"CNN (After Outlier Removal) - RMSE: {cnn_rmse}, MAE: {cnn_mae}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1375298.1250
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1383393.6250
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1316089.5000
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1159243.5000
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 869834.5000
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 633119.8125
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 428644.2500
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 355358.5312
# Epoch 9/50
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_no_outliers.hist(figsize=(12, 10), bins=20, edgecolor="black")
plt.suptitle("Histogram of All Features", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x="Stock In Vast or Limited Quantity", data=df_no_outliers)
plt.title("Stock Quantity Type Distribution")
plt.show()

# %%
num_cols = ["Price", "Rating", "NumReviews", "StockQuantity", "Discount"]
plt.figure(figsize=(12, 8))

for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 3, i)
    sns.scatterplot(x=df_no_outliers[col], y=df_no_outliers["Sales"])
    plt.title(f"Sales vs. {col}")

plt.tight_layout()
plt.show()

# %%
sns.pairplot(df_no_outliers[["Price", "Rating", "NumReviews", "StockQuantity", "Discount", "Sales"]])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df_no_outliers.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from scipy.stats import ttest_ind


randomforest_rmse_values = []
svr_rmse_values = []

# Run multiple evaluations to collect RMSE values
for _ in range(10):
    # Split dataset into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_scaled_clean, y_clean, test_size=0.2, random_state=42)

    # --- Random Forest Regressor ---
    rf = RandomForestRegressor(n_estimators=100)
    rf.fit(X_train, y_train)
    rf_preds = rf.predict(X_test)
    rf_rmse = np.sqrt(mean_squared_error(y_test, rf_preds))
    randomforest_rmse_values.append(rf_rmse)

    # --- Support Vector Regressor ---
    svr = SVR()
    svr.fit(X_train, y_train)
    svr_preds = svr.predict(X_test)
    svr_rmse = np.sqrt(mean_squared_error(y_test, svr_preds))
    svr_rmse_values.append(svr_rmse)

# Print RMSEs
print("RandomForest RMSEs:", randomforest_rmse_values)
print("SVR RMSEs:", svr_rmse_values)

# --- Perform t-test ---
t_stat, p_value = ttest_ind(randomforest_rmse_values, svr_rmse_values)
print(f"\nT-test Result:")
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")
# Out:
# RandomForest RMSEs: [np.float64(610.2107357290594), np.float64(610.6968374177159), np.float64(612.3714041792775), np.float64(598.439749444754), np.float64(612.1563187519998), np.float64(605.3726707599212), np.float64(606.69857368878), np.float64(611.1958621240003), np.float64(614.0984661697178), np.float64(608.5956477222787)]
# SVR RMSEs: [np.float64(588.6869465974419), np.float64(588.6869465974419), np.float64(588.6869465974419), np.float64(588.6869465974419), np.float64(588.6869465974419), np.float64(588.6869465974419), np.float64(588.6869465974419), np.float64(588.6869465974419), np.float64(588.6869465974419), np.float64(588.6869465974419)]
#
# T-test Result:
# T-statistic: 14.09492375428516
# P-value: 3.634799664746163e-11
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
# ...

# %%
import matplotlib.pyplot as plt

plt.boxplot([randomforest_rmse_values, svr_rmse_values], labels=["Random Forest", "SVR"])
plt.ylabel("RMSE")
plt.title("Model RMSE Comparison")
plt.show()
# Out:
# <ipython-input-40-c338a399e245>:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([randomforest_rmse_values, svr_rmse_values], labels=["Random Forest", "SVR"])

# %%
from scipy.stats import ttest_1samp

baseline_rmse = 10
t_stat, p_value = ttest_1samp(randomforest_rmse_values, popmean=baseline_rmse)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: 415.96106094347635
# P-value: 1.3655396778916326e-20

# %%
from scipy.stats import ttest_1samp

baseline_rmse = 10
t_stat, p_value = ttest_1samp(svr_rmse_values, popmean=baseline_rmse)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: 1.5270552639025832e+16
# P-value: 1.1276596526210165e-142
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
import numpy as np
from scipy.stats import norm


# Sample stats
sample_mean = np.mean(svr_rmse_values)
sample_std = np.std(svr_rmse_values, ddof=1)
n = len(svr_rmse_values)

# Baseline RMSE to compare against
baseline_rmse = 4.0

# Z-statistic
z_stat = (sample_mean - baseline_rmse) / (sample_std / np.sqrt(n))

# Two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")
# Out:
# Z-statistic: 1.5428882313425578e+16
# P-value: 0.0

# %%
import numpy as np
from scipy.stats import norm


# Sample stats
sample_mean = np.mean(randomforest_rmse_values)
sample_std = np.std(randomforest_rmse_values, ddof=1)
n = len(randomforest_rmse_values)

# Baseline RMSE to compare against
baseline_rmse = 4.0

# Z-statistic
z_stat = (sample_mean - baseline_rmse) / (sample_std / np.sqrt(n))

# Two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")
# Out:
# Z-statistic: 420.1277297050797
# P-value: 0.0

# %%
mean1 = np.mean(randomforest_rmse_values)
mean2 = np.mean(svr_rmse_values)
std1 = np.std(randomforest_rmse_values, ddof=1)
std2 = np.std(svr_rmse_values, ddof=1)
n1 = len(randomforest_rmse_values)
n2 = len(svr_rmse_values)

# Z-statistic
z_stat = (mean1 - mean2) / np.sqrt((std1**2 / n1) + (std2**2 / n2))

# Two-tailed p-value
p_value = 2 * (1 - norm.cdf(abs(z_stat)))

print(f"Z-statistic: {z_stat}")
print(f"P-value: {p_value}")
# Out:
# Z-statistic: 14.09492375428516
# P-value: 0.0
